# %% [markdown]
# # Camera Quality Check

# %%
# %load_ext autoreload
# %autoreload 2

import sys, os
sys.path.append('.')
sys.path.append('..')
from common.utils import get_data_dir, gpu_ram_config, clean_folder
import logging
from common.log import init_logging
from service_cameraQualityCheck.cam_quality_check_main import f45_cam_check, f68_cam_check
from cam_image_reflash_main import reflash_f45_img, reflash_f68_img
DATA_DIR = get_data_dir()

# %%
output_dir = os.path.join(DATA_DIR, 'camera_quality_check')
clean_folder(output_dir)

# %%
init_logging('CamQualityCheck')
f45_cam_check(debug=True)
# Out:
# Load YOLO Model from /mnt/hdd1/Model/f45movement/model/yolov4-tiny-f45-0721_best.weights
# WARNING:tensorflow:From /mnt/hdd/IP_Camera_Installation/ipcamera-env/lib/python3.6/site-packages/tensorflow/python/ops/array_ops.py:5049: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# WARNING:tensorflow:From /mnt/hdd/IP_Camera_Installation/ipcamera-env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:602: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# Load MaskRCNN Model from /mnt/hdd1/Model/f45movement/model/maskrcnn_0505v2_best.h5
# warning! use replay mode

# %%
f68_cam_check(debug=True)

# %%
reflash_f45_img(debug=True)
reflash_f68_img(debug=True)

# %%
reflash_f68_img(debug=True)
